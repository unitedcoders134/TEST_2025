# %%
---
layout: post
title:  Study Guide APCSP
description:  Study Guide ACSP
permalink: /study_guide/
courses: { csp: {week 1} } 
comments: true
sticky_rank: 1
---

# %% [markdown]
# # 🌟 AP Computer Science Principles Comprehensive Study Guide
# ---
#
# ## 📽️ Video References & Guiding Questions
#
# ### 💡 Big Idea 1: Creative Development
#
# **Video Resource:**
# [AP CS Principles: Creative Development Review](https://www.youtube.com/watch?v=R1UAnYoduMk)
#
# **Guiding Question:**
# *Explain how abstraction can help manage complexity in a program. Provide an example.*
#
# ---
#
# ### 📊 Big Idea 2: Data
#
# **Video Resource:**
# [UTeach Computer Science AP CS Principles Unit 3: Data Representation](https://www.youtube.com/watch?v=CiOMZ8nBDsY)
#
# **Guiding Question:**
# *Describe the difference between lossy and lossless data compression. Give an example of each.*
#
# ---
#
# ### 👨‍💻 Big Idea 3: Algorithms and Programming
#
# **Video Resource:**
# [AP CS Principles: Algorithms and Programming Review](https://www.youtube.com/watch?v=i1gizMIXhso)
#
# **Guiding Question:**
# *Write a pseudocode algorithm that searches for a specific value in a list using linear search.*
#
# ---
#
# ### 🌐 Big Idea 4: Computing Systems and Networks
#
# **Video Resource:**
# [AP CS Principles: The Internet and Networks Review](https://www.youtube.com/watch?v=0VmaYXV1FnU)
#
# **Guiding Question:**
# *Explain how the Domain Name System (DNS) works and why it's important for internet functionality.*
#
# ---
#
# ### 🌍 Big Idea 5: Impact of Computing
#
# **Video Resource:**
# [AP CS Principles: Impact of Computing (Review)](https://www.youtube.com/watch?v=oXiUoeM584g)
#
# **Guiding Question:**
# *Discuss how the digital divide can affect access to computing resources in different communities.*
#
# ---
#
# ## 🗂️ Big Idea Summaries
#
# ### 💡 Big Idea 1: Creative Development
#
# | Concept           | Description                                                            |
# |------------------|------------------------------------------------------------------------|
# | **Program**       | Set of instructions to solve problems or automate tasks.              |
# | **Algorithm**     | Step-by-step instructions. Includes sequencing, selection, iteration. |
# | **Abstraction**   | Hides complexity to focus on key ideas.                               |
# | **Development Cycle** | Plan → Code → Test → Refine                                       |
# | **Collaboration** | Improves ideas and bug-finding.                                       |
#
# ---
#
# ### 📊 Big Idea 2: Data
#
# | Concept            | Description                                                    |
# |-------------------|----------------------------------------------------------------|
# | **Binary**         | All digital data = 0s and 1s.                                  |
# | **Data Types**     | Integer, float, string, Boolean                                |
# | **Lists/Arrays**   | Store multiple items in one variable.                          |
# | **Data Abstraction** | Organize large/complex data with lists, dictionaries.       |
# | **Visualization**  | Graphs, charts help spot trends.                              |
#
# ---
#
# ### 👨‍💻 Big Idea 3: Algorithms and Programming
#
# | Concept               | Description                                      |
# |----------------------|--------------------------------------------------|
# | **Sequencing**        | Code runs in order.                             |
# | **Selection**         | Code chooses with `if/else`.                    |
# | **Iteration**         | Code repeats with loops.                        |
# | **Functions/Procedures** | Named reusable code blocks.                 |
# | **Parameters**        | Allow flexible input into functions.            |
# | **Return Values**     | Output from a function.                         |
# | **Debugging**         | Find and fix errors in code.                    |
#
# ---
#
# ### 🌐 Big Idea 4: Systems and Networks
#
# | Concept            | Description                                                    |
# |-------------------|----------------------------------------------------------------|
# | **Internet**        | Network of devices and protocols.                             |
# | **IP Address**      | Unique ID for a device on a network.                          |
# | **DNS**             | Converts domain names to IPs.                                 |
# | **Packets**         | Small chunks of data for transfer.                            |
# | **TCP/IP**          | Protocols that ensure delivery.                               |
# | **Cybersecurity**   | Encryption, phishing, malware, DDoS.                          |
# | **Fault Tolerance** | Network keeps working despite issues.                         |
#
# ---
#
# ### 🌍 Big Idea 5: Impact of Computing
#
# | Concept             | Description                                                        |
# |--------------------|--------------------------------------------------------------------|
# | **Ethics**          | Data ownership, privacy, bias.                                     |
# | **Digital Divide**  | Unequal access to tech.                                            |
# | **Crowdsourcing**   | Public contributions (Wikipedia).                                  |
# | **Creative Commons**| Legal software/media use.                                          |
# | **Automation**      | Computers replacing manual work.                                   |
#
# ---
#
# ## 🔐 Cybersecurity Concepts
#
# | Concept               | Description                                  |
# |----------------------|----------------------------------------------|
# | **Malware**            | Harmful software                            |
# | **Phishing**           | Fake messages to steal info                 |
# | **Symmetric Encryption** | Same key for encrypt/decrypt             |
# | **Asymmetric Encryption** | Public/private key system               |
# | **Authentication**     | Verifying identity                         |
# | **Firewalls**          | Monitor/control traffic                    |
#
# ---
#
# ## 🧾 Key Vocabulary
#
# | Term                   | Definition                                      |
# |------------------------|-------------------------------------------------|
# | **Abstraction**         | Simplifying complex problems                    |
# | **Algorithm**           | Step-by-step procedure                          |
# | **Binary**              | Base-2 number system                            |
# | **Encryption**          | Encoding to protect info                        |
# | **Lossless Compression**| No data lost (PNG, ZIP)                         |
# | **Lossy Compression**   | Some data removed (JPEG, MP3)                   |
# | **Overflow Error**      | Number exceeds memory limit                     |
# | **Heuristic**           | Approximation method                            |
# | **Simulation**          | Models real-world processes                     |
# | **Boolean**             | True/false values                               |
# | **Event-Driven Programming** | Code reacts to events                    |
# | **Undecidable Problem** | No algorithm solves it in all cases (e.g. halting problem) |
#
# ---
#
# ## 🧪 Create Task Tips
#
# ✅ Write a program with:
# - A student-developed algorithm
# - Sequencing, selection (if), and iteration (loop)
# - A function with a **parameter**
# - A **list** to manage complexity
#
# ✅ Include:
# - 1-minute video of the program
# - Two screenshots:
#   - Function definition + call
#   - List creation + use
#
# ✅ Written responses:
# - Describe your algorithm clearly
# - Explain use of abstraction
# - Justify how the list simplifies the program
#
# ---
#
# ## 📝 Exam Format Overview
#
# | Section             | Details                          |
# |---------------------|----------------------------------|
# | **MCQs (70%)**       | ~70 multiple-choice questions    |
# | **Create Task (30%)**| Code, video, and explanation     |
#
# ---
#
# ## 📈 Study Tips
#
# - 🧠 Practice writing and tracing pseudocode.  [College Board Vocab] (https://quizlet.com/215446996/ap-computer-science-principles-vocabulary-flash-cards/)
# - 🧪 Use [College Board’s Guiding Questions](https://apstudents.collegeboard.org) regularly.
# - 🎥 Review your **Create Task** submission and rubrics.
# - 🃏 Use flashcards to quiz key vocabulary.
# - 💡 Understand both positive and negative impacts of technology.

# %% [markdown]
# ## 📚 Study & Review Plan: Weak Topics
#
# Based on recent performance data, here are the topics I need to focus on most, along with how I plan to improve:
#
# <img src="{{site.baseurl}}/images/mcqresults.png" width="750px">
#
# ### 🔢 3.3 Mathematical Expressions — *Scored: 33%*
# - **Review Plan:**
#   - Watch: [Mathematical Expressions in AP CSP](https://www.youtube.com/watch?v=VGmdugI2v7A)
#   - Review how operators work (`+`, `-`, `*`, `/`, `%`) and practice tracing evaluation of expressions.
#   - Work on practice problems involving operator precedence and integer vs float division.
# - **Practice Question:**
#   *What is the output of the following expression: `((5 + 3) * 2) % 4`?*
#
# ---
#
# ### 🔡 3.4 Strings — *Scored: 0%*
# - **Review Plan:**
#   - Watch: [AP CSP Strings & String Operations](https://www.youtube.com/watch?v=rnrL9dzEHqQ)
#   - Practice accessing characters, slicing, and using string methods like `.length`, `.substring()`, and concatenation.
# - **Practice Question:**
#   *What does `str[1:4]` return if `str = "Hello"`?*
#
# ---
#
# ### 🔘 3.5 Boolean Expressions — *Scored: 25%*
# - **Review Plan:**
#   - Watch: [Boolean Logic Crash Course](https://www.youtube.com/watch?v=v4bb8NM1vs4)
#   - Revisit comparison operators (`==`, `!=`, `<`, `>`, `<=`, `>=`) and logical operators (`and`, `or`, `not`).
#   - Use truth tables to better understand logic combinations.
# - **Practice Question:**
#   *Evaluate: `(5 > 3) and (2 == 2) or (4 < 1)`*
#
# ---
#
# ### 🔁 3.6 Conditionals — *Scored: 33%*
# - **Review Plan:**
#   - Watch: [Conditionals in Python/AP CSP](https://www.youtube.com/watch?v=ijGS2awzmZI)
#   - Practice writing `if`, `if-else`, and `if-elif-else` statements.
#   - Focus on understanding flowcharts and tracing conditional logic.
# - **Practice Question:**
#   *What will the following code print?
#   ```python
#   score = 75
#   if score > 90:
#       print("A")
#   elif score > 80:
#       print("B")
#   elif score > 70:
#       print("C")
#   else:
#       print("D")
#   ```*
#
# ---
#
# ### 🎲 3.15 Random Values — *Scored: 0%*
# - **Review Plan:**
#   - Watch: [Random Values Explained](https://www.youtube.com/watch?v=EbZX4U0-ZFo)
#   - Practice generating random integers, understanding randomness ranges, and simulating games or dice rolls.
# - **Practice Question:**
#   *What values can `random.randint(1, 6)` return? How is this used in simulating a dice roll?*
#
# ---
#
# ### 🌍 5.2 Digital Divide — *Scored: 0%*
# - **Review Plan:**
#   - Watch: [AP CSP: Digital Divide](https://www.youtube.com/watch?v=BIH2xK2UekA)
#   - Reflect on how access to computing impacts opportunities in different communities.
#   - Look into real-world examples of geographic and economic factors affecting access.
# - **Practice Question:**
#   *Describe one way the digital divide affects education or job opportunities.*
#
# ---
