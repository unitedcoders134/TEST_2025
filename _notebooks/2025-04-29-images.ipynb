# %%
---
layout: post
title:   Images, Base64, Color Codes
description:  Popcorn + Homework + Extra Credit
permalink: /popcorn_homework_ec/
courses: { csp: {week 1} } 
comments: true
sticky_rank: 1
---

# %% [markdown]
# ## Popcorn Hack 1
#
# An alpha transparency would b useful in making logos.
#
# ## Popcorn Hack 2
#
# Which would be the bst with a transparent image -
#
# The answer is png as you only need the least amount of data
#
# ## Popcorn Hack 3
#
# What do you think could be one downside of Base64 in the real world?
#
#  Increased Data Size: - Base64 encoding adds about 33% more data. On top of this, anyone can easily decode base64 as it's not encrypted.
#
#
# ## MCQ Questions:
#
# Which of the following is true about Base64 encoding?
#
# - A. It encrypts data to make it secure.
# - B. It increases the size of the data.
# - C. It reduces the size of the data.
# - D. It ensures data is unreadable by humans.
# Reveal Answer
# Correct Answer: B. It increases the size of the data.
#
# Base64 encoding increases the size of data, as it converts binary data into text characters.

# %% [markdown]
# ## Homework + Extra Credit
#
# ✅ What is a hex color code?
# A hex color code is a 6-digit code used in HTML, CSS, and design tools to represent colors. It uses the hexadecimal (base-16) numbering system.
#
# Each pair of digits represents the intensity of red, green, and blue (RGB) respectively:
#
# yaml
# Copy
# Edit
# Format: #RRGGBB
# RR = red (00 to FF in hex, or 0 to 255 in decimal)
#
# GG = green
#
# BB = blue
#
# 🔹 Examples:
# #FFFFFF → white
#
# #000000 → black
#
# #FF0000 → red
#
# #00FF00 → green
#
# #0000FF → blue
#
# #1E90FF → dodger blue
#
# 💻 Application to My Work:
# In my educational website project, I used #1E1E2F as a background color to give a modern, dark-themed UI for students accessing lessons.
#
# ✅ What is Base64 and how is it used with images?
# Base64 is a method of encoding binary data (like images) into a text string using 64 characters (A–Z, a–z, 0–9, +, /). This allows binary data to be safely embedded in text-based formats such as HTML, CSS, or JSON.
#
# 🔹 For images:
# You can convert an image (like .png or .jpg) to a Base64 string and embed it directly inside an HTML <img> tag:
#
# html
# Copy
# Edit
#
#
# ✅ Why might you use Base64 instead of a regular image file?
# Using Base64 images is helpful when:
#
# ✅ You want fewer HTTP requests (faster page loads for small images).
#
# ✅ You're embedding images directly into emails or JSON responses.
#
# ✅ You're working on a self-contained web page (like for GitHub Pages without needing external assets).
#
# ✅ You want to avoid broken image links when deploying static sites.
#
# However, Base64 increases the file size by ~33%, so it’s better for small icons or logos, not large photos.
#
# 💻 Application to My Work:
# In my Flask frontend, I used Base64 to embed a default avatar image directly into the HTML so the site wouldn't rely on loading external image files from a static folder.
#
# <img src="{{site.baseurl}}/images/leaderboardsystem.png" width="750px">
#
# The image above is being stored as a file in the project's directory, not as base 64 or inline.
#
# Stored as a PNG file in your site's images/ folder.
#
# Linked via a relative path using the {{site.baseurl}} placeholder.
#
# Loaded as a standard external file, not embedded or Base64 encoded.
#
#
# | Color Name    | RGB Code             | Hex Code    |
# |---------------|----------------------|-------------|
# | Red           | `rgb(255, 0, 0)`     | `#FF0000`   |
# | Lime          | `rgb(0, 255, 0)`     | `#00FF00`   |
# | Blue          | `rgb(0, 0, 255)`     | `#0000FF`   |
# | Orange        | `rgb(255, 165, 0)`   | `#FFA500`   |
# | Medium Purple | `rgb(147, 112, 219)` | `#9370DB`   |
