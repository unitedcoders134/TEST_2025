# %%
---
layout: post
title:  MCQ Analysis 2
description:  MCQ Analysis + Corrections
permalink: /mcq-analysis-2/
courses: { csp: {week 1} } 
comments: true
sticky_rank: 1
---

# %% [markdown]
# **Analytics**
#
# <img src="{{site.baseurl}}/images/mcq accuracy.png" width="750px">
#
# - Accuracy has improved 13% over the 12 weeks
#
# Graph Containing Averager time per question Averaged every five questions (excluding outliers) for MCQ One
#
# <img src="{{site.baseurl}}/images/timing 1.png" width="750px">
#
#
# Vs MCQ 2:
#
# <img src="{{site.baseurl}}/images/timing 2.png" width="750px">
#
#
# Time: Spending over a minute per question consistently. Some outliers weren't excluded
#
#
#
# Corrections, Strenghts, and Weaknesses:
#
# **Strenghts**
#
# Last MCQ: Strenghts included Variables & Assignments, Nested Conditionals, Beneficial & Harmful Effects, & Legal & Ethical Concernts, Crowdsourcing.
#
# <img src="{{site.baseurl}}/images/mcq.png" width="750px">
#
# This MCQ: All of my strenghts were still at a 100%, and I managed to bring up some of my weaknesses as well.
#
# <img src="{{site.baseurl}}/images/strenghts vs weaknesses.png" width="750px">
#
# **Weaknesses**
#
#
# Last MC:
#
# - Binary Numberings: 50% of the problems right
# - Calling Procedures: 50% Accuracy
#
# This MC:
#  - Binary Numbers: 80% Accuracy
#  - Calling Procedures: 80% Accuracy.
#
#
#
# **Room for Improvement**
#
# Developing Algorythms: 70&
#
# Simulations: 50%
#
# **Corrections**
#
# <img src="{{site.baseurl}}/images/mcq 0.png" width="750px">
#
# The Loop Terminates After 10 and prints before adding a value; therefore my answer choice was wrong.
#
# <img src="{{site.baseurl}}/images/mcq1.png" width="750px">
#
# This operation indexes beetwen lines 7 and 8 which is when the function is called.
#
# <img src="{{site.baseurl}}/images/mcq2.png" width="750px">
#
# The segment only rotates it right once, then attempts to move it into a black section. This would cause an error.
#
#
# <img src="{{site.baseurl}}/images/mcq 3.png" width="750px">
#
# The average amount from the pie chart was about 10 GB. Look closer.
#
# <img src="{{site.baseurl}}/images/mcq 4.png" width="750px">
#
# Metadata normally consisnts of descriptive info, not the copy istelf.
#
# <img src="{{site.baseurl}}/images/mcq 5.png" width="750px">
#
# My choice was incorrects, the values of alpha and beta are interchanged. . Code segments assign the initial value, then that value assigned to beta. Temp isn't being stored at the same value as alpha.
#
# <img src="{{site.baseurl}}/images/mcq 6.png" width="750px">
#
# My answer is determined by the sum of lower scores after the lowest score was dropped. The value of the highest determined score can be determined algebraicly.
#
# <img src="{{site.baseurl}}/images/mcq 7.png" width="750px">
#
# It doesn't generalize to calculate any number of values. numList returns the maximum value of the list in numLits
#
# <img src="{{site.baseurl}}/images/mcq 8.png" width="750px">
#
# i has to be incremented bfore being added into sums. This program will now include all of the first 10 elements of the list when they compute the usm.
#
# <img src="{{site.baseurl}}/images/mcq 9.png" width="750px">
#
# A binary search works on any sorted list - regardless of whether it contains duplicate values. However, values have to be sorted before searched.
#
# <img src="{{site.baseurl}}/images/mcq 10.png" width="750px">
#
# Version II requires more than a minute because the function is being called twice.
#
# <img src="{{site.baseurl}}/images/mcq 11.png" width="750px">
#
# Correct protocals like TCP and IP standard a format for messages being sent from devices on the internet
